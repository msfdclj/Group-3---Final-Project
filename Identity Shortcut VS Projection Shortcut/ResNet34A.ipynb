# %%
import keras
from keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Dense, Flatten, Dropout, Add, Activation, Input, BatchNormalization, ZeroPadding2D
from keras.models import Model
from keras.optimizers import Adam, SGD
from keras.utils import np_utils
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
#import data
import h5py
import numpy as np

train_set = h5py.File('train_signs.h5', 'r')
train_x = np.array(train_set['train_set_x'][:])
train_y = np.array(train_set['train_set_y'][:])
classes = np.array(train_set['list_classes'].shape[0])

test_set = h5py.File('test_signs.h5', 'r')
test_x = np.array(test_set['test_set_x'][:])
test_y = np.array(test_set['test_set_y'][:])

# %%
#show our data
plt.imshow(train_x[0])
print('The label of this picture is', train_y[0])
print('There are', classes, 'classes')
# Out:
# The label of this picture is 5
# There are 6 classes

# %%
#data preprocessing
x_train = train_x / 255
x_test = test_x / 255

y_train = np_utils.to_categorical(train_y)
y_test = np_utils.to_categorical(test_y)

print('trainset has', x_train.shape[0], 'pictures')
print('dataset has', x_test.shape[0], 'pictures')
print('the shape of train data is', x_train.shape)
print('the shape of test data is', x_test.shape)
# Out:
# trainset has 1080 pictures
# dataset has 120 pictures
# the shape of train data is (1080, 64, 64, 3)
# the shape of test data is (120, 64, 64, 3)

# %%
def identity_block(x, f):
    
    x_shortcut = x
    
    #convolution path
    x = Conv2D(filters = f, kernel_size = (3, 3), strides = (1, 1), padding = 'same')(x)
    x = BatchNormalization(axis = 3)(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters = f, kernel_size = (3, 3), strides = (1, 1), padding = 'same')(x)
    x = BatchNormalization(axis = 3)(x)
    x = Activation('relu')(x)
    
    #add
    x = Add()([x, x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
def convolutional_block(x, f):
    
    x_shortcut = x
    
    #convolution path
    x = Conv2D(filters = f, kernel_size = (3, 3), strides = (2, 2), padding = 'same')(x)
    x = BatchNormalization(axis = 3)(x)
    x = Activation('relu')(x)
    
    x = Conv2D(filters = f, kernel_size = (3, 3), strides = (1, 1), padding = 'same')(x)
    x = BatchNormalization(axis = 3)(x)
    x = Activation('relu')(x)
    
    #identity path
    x_shortcut = ZeroPadding2D(padding=(0, int(f / 4)), dim_ordering='channels_first')(x_shortcut)
    x_shortcut = MaxPooling2D((2, 2), strides = (2, 2), padding = 'same')(x_shortcut)
    
    #add
    x = Add()([x, x_shortcut])
    x = Activation('relu')(x)
    
    return x

# %%
x_input = Input(shape = (64, 64, 3))

x = ZeroPadding2D((3, 3))(x_input)

x = Conv2D(64, (7, 7), strides = (2, 2))(x)
x = BatchNormalization(axis = 3)(x)
x = Activation('relu')(x)
x = MaxPooling2D((3, 3), strides = (2, 2))(x)

x = identity_block(x, 64)
x = identity_block(x, 64)
x = identity_block(x, 64)

x = convolutional_block(x, 128)
x = identity_block(x, 128)
x = identity_block(x, 128)
x = identity_block(x, 128)

x = convolutional_block(x, 256)
x = identity_block(x, 256)
x = identity_block(x, 256)
x = identity_block(x, 256)
x = identity_block(x, 256)
x = identity_block(x, 256)

x = convolutional_block(x, 512)
x = identity_block(x, 512)
x = identity_block(x, 512)

x = AveragePooling2D((2, 2))(x)
x = Flatten()(x)
x = Dense(classes, activation = 'softmax')(x)

model = Model(inputs = x_input, outputs = x)

model.summary()
# Out:
# /home/gzc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(0, 32), data_format="channels_first")`
#   from ipykernel import kernelapp as app
# /home/gzc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(0, 64), data_format="channels_first")`
#   from ipykernel import kernelapp as app
# /home/gzc/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Update your `ZeroPadding2D` call to the Keras 2 API: `ZeroPadding2D(padding=(0, 128), data_format="channels_first")`
#   from ipykernel import kernelapp as app
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3980: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_14 (InputLayer)           (None, 64, 64, 3)    0
# __________________________________________________________________________________________________
# zero_padding2d_24 (ZeroPadding2 (None, 70, 70, 3)    0           input_14[0][0]
# __________________________________________________________________________________________________
# conv2d_118 (Conv2D)             (None, 32, 32, 64)   9472        zero_padding2d_24[0][0]
# __________________________________________________________________________________________________
# batch_normalization_118 (BatchN (None, 32, 32, 64)   256         conv2d_118[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 32, 32, 64)   0           batch_normalization_118[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_15 (MaxPooling2D) (None, 15, 15, 64)   0           activation_157[0][0]
# __________________________________________________________________________________________________
# conv2d_119 (Conv2D)             (None, 15, 15, 64)   36928       max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_119 (BatchN (None, 15, 15, 64)   256         conv2d_119[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 15, 15, 64)   0           batch_normalization_119[0][0]
# __________________________________________________________________________________________________
# conv2d_120 (Conv2D)             (None, 15, 15, 64)   36928       activation_158[0][0]
# __________________________________________________________________________________________________
# batch_normalization_120 (BatchN (None, 15, 15, 64)   256         conv2d_120[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 15, 15, 64)   0           batch_normalization_120[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, 15, 15, 64)   0           activation_159[0][0]
#                                                                  max_pooling2d_15[0][0]
# __________________________________________________________________________________________________
# activation_160 (Activation)     (None, 15, 15, 64)   0           add_52[0][0]
# __________________________________________________________________________________________________
# conv2d_121 (Conv2D)             (None, 15, 15, 64)   36928       activation_160[0][0]
# __________________________________________________________________________________________________
# batch_normalization_121 (BatchN (None, 15, 15, 64)   256         conv2d_121[0][0]
# __________________________________________________________________________________________________
# activation_161 (Activation)     (None, 15, 15, 64)   0           batch_normalization_121[0][0]
# __________________________________________________________________________________________________
# conv2d_122 (Conv2D)             (None, 15, 15, 64)   36928       activation_161[0][0]
# __________________________________________________________________________________________________
# batch_normalization_122 (BatchN (None, 15, 15, 64)   256         conv2d_122[0][0]
# __________________________________________________________________________________________________
# activation_162 (Activation)     (None, 15, 15, 64)   0           batch_normalization_122[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, 15, 15, 64)   0           activation_162[0][0]
#                                                                  activation_160[0][0]
# __________________________________________________________________________________________________
# activation_163 (Activation)     (None, 15, 15, 64)   0           add_53[0][0]
# __________________________________________________________________________________________________
# conv2d_123 (Conv2D)             (None, 15, 15, 64)   36928       activation_163[0][0]
# __________________________________________________________________________________________________
# batch_normalization_123 (BatchN (None, 15, 15, 64)   256         conv2d_123[0][0]
# __________________________________________________________________________________________________
# activation_164 (Activation)     (None, 15, 15, 64)   0           batch_normalization_123[0][0]
# __________________________________________________________________________________________________
# conv2d_124 (Conv2D)             (None, 15, 15, 64)   36928       activation_164[0][0]
# __________________________________________________________________________________________________
# batch_normalization_124 (BatchN (None, 15, 15, 64)   256         conv2d_124[0][0]
# __________________________________________________________________________________________________
# activation_165 (Activation)     (None, 15, 15, 64)   0           batch_normalization_124[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, 15, 15, 64)   0           activation_165[0][0]
#                                                                  activation_163[0][0]
# __________________________________________________________________________________________________
# activation_166 (Activation)     (None, 15, 15, 64)   0           add_54[0][0]
# __________________________________________________________________________________________________
# conv2d_125 (Conv2D)             (None, 8, 8, 128)    73856       activation_166[0][0]
# __________________________________________________________________________________________________
# batch_normalization_125 (BatchN (None, 8, 8, 128)    512         conv2d_125[0][0]
# __________________________________________________________________________________________________
# activation_167 (Activation)     (None, 8, 8, 128)    0           batch_normalization_125[0][0]
# __________________________________________________________________________________________________
# conv2d_126 (Conv2D)             (None, 8, 8, 128)    147584      activation_167[0][0]
# __________________________________________________________________________________________________
# batch_normalization_126 (BatchN (None, 8, 8, 128)    512         conv2d_126[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_25 (ZeroPadding2 (None, 15, 15, 128)  0           activation_166[0][0]
# __________________________________________________________________________________________________
# activation_168 (Activation)     (None, 8, 8, 128)    0           batch_normalization_126[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_16 (MaxPooling2D) (None, 8, 8, 128)    0           zero_padding2d_25[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, 8, 8, 128)    0           activation_168[0][0]
#                                                                  max_pooling2d_16[0][0]
# __________________________________________________________________________________________________
# activation_169 (Activation)     (None, 8, 8, 128)    0           add_55[0][0]
# __________________________________________________________________________________________________
# conv2d_127 (Conv2D)             (None, 8, 8, 128)    147584      activation_169[0][0]
# __________________________________________________________________________________________________
# batch_normalization_127 (BatchN (None, 8, 8, 128)    512         conv2d_127[0][0]
# __________________________________________________________________________________________________
# activation_170 (Activation)     (None, 8, 8, 128)    0           batch_normalization_127[0][0]
# __________________________________________________________________________________________________
# conv2d_128 (Conv2D)             (None, 8, 8, 128)    147584      activation_170[0][0]
# __________________________________________________________________________________________________
# batch_normalization_128 (BatchN (None, 8, 8, 128)    512         conv2d_128[0][0]
# __________________________________________________________________________________________________
# activation_171 (Activation)     (None, 8, 8, 128)    0           batch_normalization_128[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, 8, 8, 128)    0           activation_171[0][0]
#                                                                  activation_169[0][0]
# __________________________________________________________________________________________________
# activation_172 (Activation)     (None, 8, 8, 128)    0           add_56[0][0]
# __________________________________________________________________________________________________
# conv2d_129 (Conv2D)             (None, 8, 8, 128)    147584      activation_172[0][0]
# __________________________________________________________________________________________________
# batch_normalization_129 (BatchN (None, 8, 8, 128)    512         conv2d_129[0][0]
# __________________________________________________________________________________________________
# activation_173 (Activation)     (None, 8, 8, 128)    0           batch_normalization_129[0][0]
# __________________________________________________________________________________________________
# conv2d_130 (Conv2D)             (None, 8, 8, 128)    147584      activation_173[0][0]
# __________________________________________________________________________________________________
# batch_normalization_130 (BatchN (None, 8, 8, 128)    512         conv2d_130[0][0]
# __________________________________________________________________________________________________
# activation_174 (Activation)     (None, 8, 8, 128)    0           batch_normalization_130[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, 8, 8, 128)    0           activation_174[0][0]
#                                                                  activation_172[0][0]
# __________________________________________________________________________________________________
# activation_175 (Activation)     (None, 8, 8, 128)    0           add_57[0][0]
# __________________________________________________________________________________________________
# conv2d_131 (Conv2D)             (None, 8, 8, 128)    147584      activation_175[0][0]
# __________________________________________________________________________________________________
# batch_normalization_131 (BatchN (None, 8, 8, 128)    512         conv2d_131[0][0]
# __________________________________________________________________________________________________
# activation_176 (Activation)     (None, 8, 8, 128)    0           batch_normalization_131[0][0]
# __________________________________________________________________________________________________
# conv2d_132 (Conv2D)             (None, 8, 8, 128)    147584      activation_176[0][0]
# __________________________________________________________________________________________________
# batch_normalization_132 (BatchN (None, 8, 8, 128)    512         conv2d_132[0][0]
# __________________________________________________________________________________________________
# activation_177 (Activation)     (None, 8, 8, 128)    0           batch_normalization_132[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, 8, 8, 128)    0           activation_177[0][0]
#                                                                  activation_175[0][0]
# __________________________________________________________________________________________________
# activation_178 (Activation)     (None, 8, 8, 128)    0           add_58[0][0]
# __________________________________________________________________________________________________
# conv2d_133 (Conv2D)             (None, 4, 4, 256)    295168      activation_178[0][0]
# __________________________________________________________________________________________________
# batch_normalization_133 (BatchN (None, 4, 4, 256)    1024        conv2d_133[0][0]
# __________________________________________________________________________________________________
# activation_179 (Activation)     (None, 4, 4, 256)    0           batch_normalization_133[0][0]
# __________________________________________________________________________________________________
# conv2d_134 (Conv2D)             (None, 4, 4, 256)    590080      activation_179[0][0]
# __________________________________________________________________________________________________
# batch_normalization_134 (BatchN (None, 4, 4, 256)    1024        conv2d_134[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_26 (ZeroPadding2 (None, 8, 8, 256)    0           activation_178[0][0]
# __________________________________________________________________________________________________
# activation_180 (Activation)     (None, 4, 4, 256)    0           batch_normalization_134[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_17 (MaxPooling2D) (None, 4, 4, 256)    0           zero_padding2d_26[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, 4, 4, 256)    0           activation_180[0][0]
#                                                                  max_pooling2d_17[0][0]
# __________________________________________________________________________________________________
# activation_181 (Activation)     (None, 4, 4, 256)    0           add_59[0][0]
# __________________________________________________________________________________________________
# conv2d_135 (Conv2D)             (None, 4, 4, 256)    590080      activation_181[0][0]
# __________________________________________________________________________________________________
# batch_normalization_135 (BatchN (None, 4, 4, 256)    1024        conv2d_135[0][0]
# __________________________________________________________________________________________________
# activation_182 (Activation)     (None, 4, 4, 256)    0           batch_normalization_135[0][0]
# __________________________________________________________________________________________________
# conv2d_136 (Conv2D)             (None, 4, 4, 256)    590080      activation_182[0][0]
# __________________________________________________________________________________________________
# batch_normalization_136 (BatchN (None, 4, 4, 256)    1024        conv2d_136[0][0]
# __________________________________________________________________________________________________
# activation_183 (Activation)     (None, 4, 4, 256)    0           batch_normalization_136[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, 4, 4, 256)    0           activation_183[0][0]
#                                                                  activation_181[0][0]
# __________________________________________________________________________________________________
# activation_184 (Activation)     (None, 4, 4, 256)    0           add_60[0][0]
# __________________________________________________________________________________________________
# conv2d_137 (Conv2D)             (None, 4, 4, 256)    590080      activation_184[0][0]
# __________________________________________________________________________________________________
# batch_normalization_137 (BatchN (None, 4, 4, 256)    1024        conv2d_137[0][0]
# __________________________________________________________________________________________________
# activation_185 (Activation)     (None, 4, 4, 256)    0           batch_normalization_137[0][0]
# __________________________________________________________________________________________________
# conv2d_138 (Conv2D)             (None, 4, 4, 256)    590080      activation_185[0][0]
# __________________________________________________________________________________________________
# batch_normalization_138 (BatchN (None, 4, 4, 256)    1024        conv2d_138[0][0]
# __________________________________________________________________________________________________
# activation_186 (Activation)     (None, 4, 4, 256)    0           batch_normalization_138[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, 4, 4, 256)    0           activation_186[0][0]
#                                                                  activation_184[0][0]
# __________________________________________________________________________________________________
# activation_187 (Activation)     (None, 4, 4, 256)    0           add_61[0][0]
# __________________________________________________________________________________________________
# conv2d_139 (Conv2D)             (None, 4, 4, 256)    590080      activation_187[0][0]
# __________________________________________________________________________________________________
# batch_normalization_139 (BatchN (None, 4, 4, 256)    1024        conv2d_139[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 4, 4, 256)    0           batch_normalization_139[0][0]
# __________________________________________________________________________________________________
# conv2d_140 (Conv2D)             (None, 4, 4, 256)    590080      activation_188[0][0]
# __________________________________________________________________________________________________
# batch_normalization_140 (BatchN (None, 4, 4, 256)    1024        conv2d_140[0][0]
# __________________________________________________________________________________________________
# activation_189 (Activation)     (None, 4, 4, 256)    0           batch_normalization_140[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, 4, 4, 256)    0           activation_189[0][0]
#                                                                  activation_187[0][0]
# __________________________________________________________________________________________________
# activation_190 (Activation)     (None, 4, 4, 256)    0           add_62[0][0]
# __________________________________________________________________________________________________
# conv2d_141 (Conv2D)             (None, 4, 4, 256)    590080      activation_190[0][0]
# __________________________________________________________________________________________________
# batch_normalization_141 (BatchN (None, 4, 4, 256)    1024        conv2d_141[0][0]
# __________________________________________________________________________________________________
# activation_191 (Activation)     (None, 4, 4, 256)    0           batch_normalization_141[0][0]
# __________________________________________________________________________________________________
# conv2d_142 (Conv2D)             (None, 4, 4, 256)    590080      activation_191[0][0]
# __________________________________________________________________________________________________
# batch_normalization_142 (BatchN (None, 4, 4, 256)    1024        conv2d_142[0][0]
# __________________________________________________________________________________________________
# activation_192 (Activation)     (None, 4, 4, 256)    0           batch_normalization_142[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, 4, 4, 256)    0           activation_192[0][0]
#                                                                  activation_190[0][0]
# __________________________________________________________________________________________________
# activation_193 (Activation)     (None, 4, 4, 256)    0           add_63[0][0]
# __________________________________________________________________________________________________
# conv2d_143 (Conv2D)             (None, 4, 4, 256)    590080      activation_193[0][0]
# __________________________________________________________________________________________________
# batch_normalization_143 (BatchN (None, 4, 4, 256)    1024        conv2d_143[0][0]
# __________________________________________________________________________________________________
# activation_194 (Activation)     (None, 4, 4, 256)    0           batch_normalization_143[0][0]
# __________________________________________________________________________________________________
# conv2d_144 (Conv2D)             (None, 4, 4, 256)    590080      activation_194[0][0]
# __________________________________________________________________________________________________
# batch_normalization_144 (BatchN (None, 4, 4, 256)    1024        conv2d_144[0][0]
# __________________________________________________________________________________________________
# activation_195 (Activation)     (None, 4, 4, 256)    0           batch_normalization_144[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, 4, 4, 256)    0           activation_195[0][0]
#                                                                  activation_193[0][0]
# __________________________________________________________________________________________________
# activation_196 (Activation)     (None, 4, 4, 256)    0           add_64[0][0]
# __________________________________________________________________________________________________
# conv2d_145 (Conv2D)             (None, 2, 2, 512)    1180160     activation_196[0][0]
# __________________________________________________________________________________________________
# batch_normalization_145 (BatchN (None, 2, 2, 512)    2048        conv2d_145[0][0]
# __________________________________________________________________________________________________
# activation_197 (Activation)     (None, 2, 2, 512)    0           batch_normalization_145[0][0]
# __________________________________________________________________________________________________
# conv2d_146 (Conv2D)             (None, 2, 2, 512)    2359808     activation_197[0][0]
# __________________________________________________________________________________________________
# batch_normalization_146 (BatchN (None, 2, 2, 512)    2048        conv2d_146[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_27 (ZeroPadding2 (None, 4, 4, 512)    0           activation_196[0][0]
# __________________________________________________________________________________________________
# activation_198 (Activation)     (None, 2, 2, 512)    0           batch_normalization_146[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_18 (MaxPooling2D) (None, 2, 2, 512)    0           zero_padding2d_27[0][0]
# __________________________________________________________________________________________________
# add_65 (Add)                    (None, 2, 2, 512)    0           activation_198[0][0]
#                                                                  max_pooling2d_18[0][0]
# __________________________________________________________________________________________________
# activation_199 (Activation)     (None, 2, 2, 512)    0           add_65[0][0]
# __________________________________________________________________________________________________
# conv2d_147 (Conv2D)             (None, 2, 2, 512)    2359808     activation_199[0][0]
# __________________________________________________________________________________________________
# batch_normalization_147 (BatchN (None, 2, 2, 512)    2048        conv2d_147[0][0]
# __________________________________________________________________________________________________
# activation_200 (Activation)     (None, 2, 2, 512)    0           batch_normalization_147[0][0]
# __________________________________________________________________________________________________
# conv2d_148 (Conv2D)             (None, 2, 2, 512)    2359808     activation_200[0][0]
# __________________________________________________________________________________________________
# batch_normalization_148 (BatchN (None, 2, 2, 512)    2048        conv2d_148[0][0]
# __________________________________________________________________________________________________
# activation_201 (Activation)     (None, 2, 2, 512)    0           batch_normalization_148[0][0]
# __________________________________________________________________________________________________
# add_66 (Add)                    (None, 2, 2, 512)    0           activation_201[0][0]
#                                                                  activation_199[0][0]
# __________________________________________________________________________________________________
# activation_202 (Activation)     (None, 2, 2, 512)    0           add_66[0][0]
# __________________________________________________________________________________________________
# conv2d_149 (Conv2D)             (None, 2, 2, 512)    2359808     activation_202[0][0]
# __________________________________________________________________________________________________
# batch_normalization_149 (BatchN (None, 2, 2, 512)    2048        conv2d_149[0][0]
# __________________________________________________________________________________________________
# activation_203 (Activation)     (None, 2, 2, 512)    0           batch_normalization_149[0][0]
# __________________________________________________________________________________________________
# conv2d_150 (Conv2D)             (None, 2, 2, 512)    2359808     activation_203[0][0]
# __________________________________________________________________________________________________
# batch_normalization_150 (BatchN (None, 2, 2, 512)    2048        conv2d_150[0][0]
# __________________________________________________________________________________________________
# activation_204 (Activation)     (None, 2, 2, 512)    0           batch_normalization_150[0][0]
# __________________________________________________________________________________________________
# add_67 (Add)                    (None, 2, 2, 512)    0           activation_204[0][0]
#                                                                  activation_202[0][0]
# __________________________________________________________________________________________________
# activation_205 (Activation)     (None, 2, 2, 512)    0           add_67[0][0]
# __________________________________________________________________________________________________
# average_pooling2d_1 (AveragePoo (None, 1, 1, 512)    0           activation_205[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 512)          0           average_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, array(6))     3078        flatten_1[0][0]
# ==================================================================================================
# Total params: 21,136,774
# Trainable params: 21,121,542
# Non-trainable params: 15,232
# __________________________________________________________________________________________________

# %%
import time
from keras.callbacks import ModelCheckpoint

model.compile(optimizer='Adam', loss='categorical_crossentropy', metrics=['accuracy'])

checkpoint = ModelCheckpoint("resnet34A.h5", monitor='val_acc', verbose=1, mode='max', save_best_only=True)

start = time.time()
history = model.fit(x_train, y_train, validation_split=0.15, epochs=100, batch_size=32, callbacks=[checkpoint])
end = time.time()

print("Total time: ", end - start)
# Out:
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/keras/optimizers.py:790: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3295: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:986: The name tf.assign_add is deprecated. Please use tf.compat.v1.assign_add instead.
#
# WARNING:tensorflow:From /home/gzc/anaconda3/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:973: The name tf.assign is deprecated. Please use tf.compat.v1.assign instead.
#
# Train on 918 samples, validate on 162 samples
# Epoch 1/100
# 918/918 [==============================] - 33s 36ms/step - loss: 3.2063 - acc: 0.5131 - val_loss: 10.5397 - val_acc: 0.2778
#
# Epoch 00001: val_acc improved from -inf to 0.27778, saving model to resnet34A.h5
# Epoch 2/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.5058 - acc: 0.8246 - val_loss: 9.0223 - val_acc: 0.2284
#
# Epoch 00002: val_acc did not improve from 0.27778
# Epoch 3/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.4035 - acc: 0.8617 - val_loss: 9.9177 - val_acc: 0.2963
#
# Epoch 00003: val_acc improved from 0.27778 to 0.29630, saving model to resnet34A.h5
# Epoch 4/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.2081 - acc: 0.9194 - val_loss: 9.1216 - val_acc: 0.2284
#
# Epoch 00004: val_acc did not improve from 0.29630
# Epoch 5/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.1110 - acc: 0.9597 - val_loss: 3.5385 - val_acc: 0.4815
#
# Epoch 00005: val_acc improved from 0.29630 to 0.48148, saving model to resnet34A.h5
# Epoch 6/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0946 - acc: 0.9662 - val_loss: 2.7554 - val_acc: 0.5247
#
# Epoch 00006: val_acc improved from 0.48148 to 0.52469, saving model to resnet34A.h5
# Epoch 7/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0786 - acc: 0.9739 - val_loss: 10.3426 - val_acc: 0.2099
#
# Epoch 00007: val_acc did not improve from 0.52469
# Epoch 8/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0465 - acc: 0.9847 - val_loss: 2.6329 - val_acc: 0.5741
#
# Epoch 00008: val_acc improved from 0.52469 to 0.57407, saving model to resnet34A.h5
# Epoch 9/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0296 - acc: 0.9913 - val_loss: 10.0191 - val_acc: 0.2222
#
# Epoch 00009: val_acc did not improve from 0.57407
# Epoch 10/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0439 - acc: 0.9815 - val_loss: 8.0641 - val_acc: 0.3025
#
# Epoch 00010: val_acc did not improve from 0.57407
# Epoch 11/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0472 - acc: 0.9837 - val_loss: 4.6901 - val_acc: 0.5185
#
# Epoch 00011: val_acc did not improve from 0.57407
# Epoch 12/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0185 - acc: 0.9935 - val_loss: 5.3446 - val_acc: 0.5309
#
# Epoch 00012: val_acc did not improve from 0.57407
# Epoch 13/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0313 - acc: 0.9880 - val_loss: 0.8547 - val_acc: 0.8025
#
# Epoch 00013: val_acc improved from 0.57407 to 0.80247, saving model to resnet34A.h5
# Epoch 14/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0217 - acc: 0.9924 - val_loss: 9.8186 - val_acc: 0.1914
#
# Epoch 00014: val_acc did not improve from 0.80247
# Epoch 15/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0580 - acc: 0.9771 - val_loss: 1.2011 - val_acc: 0.6790
#
# Epoch 00015: val_acc did not improve from 0.80247
# Epoch 16/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0457 - acc: 0.9847 - val_loss: 11.2585 - val_acc: 0.1914
#
# Epoch 00016: val_acc did not improve from 0.80247
# Epoch 17/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.1299 - acc: 0.9608 - val_loss: 13.8648 - val_acc: 0.1296
#
# Epoch 00017: val_acc did not improve from 0.80247
# Epoch 18/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.1989 - acc: 0.9499 - val_loss: 8.6101 - val_acc: 0.3642
#
# Epoch 00018: val_acc did not improve from 0.80247
# Epoch 19/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.1163 - acc: 0.9564 - val_loss: 12.4295 - val_acc: 0.1852
#
# Epoch 00019: val_acc did not improve from 0.80247
# Epoch 20/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0500 - acc: 0.9793 - val_loss: 6.0636 - val_acc: 0.4136
#
# Epoch 00020: val_acc did not improve from 0.80247
# Epoch 21/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0284 - acc: 0.9913 - val_loss: 1.7421 - val_acc: 0.6481
#
# Epoch 00021: val_acc did not improve from 0.80247
# Epoch 22/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0286 - acc: 0.9891 - val_loss: 2.4105 - val_acc: 0.6667
#
# Epoch 00022: val_acc did not improve from 0.80247
# Epoch 23/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0115 - acc: 0.9967 - val_loss: 0.3534 - val_acc: 0.9321
#
# Epoch 00023: val_acc improved from 0.80247 to 0.93210, saving model to resnet34A.h5
# Epoch 24/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0027 - acc: 0.9989 - val_loss: 0.3731 - val_acc: 0.8889
#
# Epoch 00024: val_acc did not improve from 0.93210
# Epoch 25/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0197 - acc: 0.9913 - val_loss: 1.4289 - val_acc: 0.7407
#
# Epoch 00025: val_acc did not improve from 0.93210
# Epoch 26/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0197 - acc: 0.9967 - val_loss: 0.5437 - val_acc: 0.8951
#
# Epoch 00026: val_acc did not improve from 0.93210
# Epoch 27/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0107 - acc: 0.9967 - val_loss: 7.3359 - val_acc: 0.3333
#
# Epoch 00027: val_acc did not improve from 0.93210
# Epoch 28/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0245 - acc: 0.9935 - val_loss: 1.7512 - val_acc: 0.7037
#
# Epoch 00028: val_acc did not improve from 0.93210
# Epoch 29/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0316 - acc: 0.9902 - val_loss: 5.2357 - val_acc: 0.4753
#
# Epoch 00029: val_acc did not improve from 0.93210
# Epoch 30/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0374 - acc: 0.9826 - val_loss: 8.6194 - val_acc: 0.3025
#
# Epoch 00030: val_acc did not improve from 0.93210
# Epoch 31/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0066 - acc: 0.9967 - val_loss: 2.3263 - val_acc: 0.4938
#
# Epoch 00031: val_acc did not improve from 0.93210
# Epoch 32/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0052 - acc: 0.9989 - val_loss: 1.7040 - val_acc: 0.6420
#
# Epoch 00032: val_acc did not improve from 0.93210
# Epoch 33/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0412 - acc: 0.9847 - val_loss: 0.3675 - val_acc: 0.9136
#
# Epoch 00033: val_acc did not improve from 0.93210
# Epoch 34/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0439 - acc: 0.9880 - val_loss: 3.1870 - val_acc: 0.5185
#
# Epoch 00034: val_acc did not improve from 0.93210
# Epoch 35/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0257 - acc: 0.9913 - val_loss: 2.2503 - val_acc: 0.6420
#
# Epoch 00035: val_acc did not improve from 0.93210
# Epoch 36/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0220 - acc: 0.9924 - val_loss: 1.3330 - val_acc: 0.8333
#
# Epoch 00036: val_acc did not improve from 0.93210
# Epoch 37/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0131 - acc: 0.9967 - val_loss: 1.7136 - val_acc: 0.7407
# Epoch 00037: val_acc did not improve from 0.93210
# Epoch 38/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0101 - acc: 0.9967 - val_loss: 0.5288 - val_acc: 0.9074
#
# Epoch 00038: val_acc did not improve from 0.93210
# Epoch 39/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0307 - acc: 0.9935 - val_loss: 3.8939 - val_acc: 0.5864
#
# Epoch 00039: val_acc did not improve from 0.93210
# Epoch 40/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0772 - acc: 0.9847 - val_loss: 10.6596 - val_acc: 0.2963
#
# Epoch 00040: val_acc did not improve from 0.93210
# Epoch 41/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0208 - acc: 0.9935 - val_loss: 9.8294 - val_acc: 0.3025
#
# Epoch 00041: val_acc did not improve from 0.93210
# Epoch 42/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0286 - acc: 0.9902 - val_loss: 5.9546 - val_acc: 0.4321
#
# Epoch 00042: val_acc did not improve from 0.93210
# Epoch 43/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0300 - acc: 0.9935 - val_loss: 11.0071 - val_acc: 0.2160
#
# Epoch 00043: val_acc did not improve from 0.93210
# Epoch 44/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0136 - acc: 0.9935 - val_loss: 2.1759 - val_acc: 0.7222
#
# Epoch 00044: val_acc did not improve from 0.93210
# Epoch 45/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0045 - acc: 0.9967 - val_loss: 1.2954 - val_acc: 0.8210
#
# Epoch 00045: val_acc did not improve from 0.93210
# Epoch 46/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0380 - acc: 0.9891 - val_loss: 0.7735 - val_acc: 0.8519
#
# Epoch 00046: val_acc did not improve from 0.93210
# Epoch 47/100
# 918/918 [==============================] - 20s 21ms/step - loss: 0.0250 - acc: 0.9891 - val_loss: 0.4648 - val_acc: 0.8827
#
# Epoch 00047: val_acc did not improve from 0.93210
# Epoch 48/100
# 918/918 [==============================] - 19s 21ms/step - loss: 0.0913 - acc: 0.9728 - val_loss: 1.1328 - val_acc: 0.8272
#
# Epoch 00048: val_acc did not improve from 0.93210
# Epoch 49/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.1952 - acc: 0.9651 - val_loss: 5.7198 - val_acc: 0.4630
#
# Epoch 00049: val_acc did not improve from 0.93210
# Epoch 50/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0466 - acc: 0.9869 - val_loss: 2.3030 - val_acc: 0.6790
#
# Epoch 00050: val_acc did not improve from 0.93210
# Epoch 51/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0226 - acc: 0.9946 - val_loss: 3.9093 - val_acc: 0.5185
#
# Epoch 00051: val_acc did not improve from 0.93210
# Epoch 52/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0247 - acc: 0.9924 - val_loss: 1.2002 - val_acc: 0.8086
#
# Epoch 00052: val_acc did not improve from 0.93210
# Epoch 53/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0078 - acc: 0.9989 - val_loss: 0.4019 - val_acc: 0.9259
#
# Epoch 00053: val_acc did not improve from 0.93210
# Epoch 54/100
# 918/918 [==============================] - 19s 20ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.4581 - val_acc: 0.9136
#
# Epoch 00054: val_acc did not improve from 0.93210
# Epoch 55/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.0536e-04 - acc: 1.0000 - val_loss: 0.3650 - val_acc: 0.9198
#
# Epoch 00055: val_acc did not improve from 0.93210
# Epoch 56/100
# 918/918 [==============================] - 19s 20ms/step - loss: 9.3197e-05 - acc: 1.0000 - val_loss: 0.2895 - val_acc: 0.9506
#
# Epoch 00056: val_acc improved from 0.93210 to 0.95062, saving model to resnet34A.h5
# Epoch 57/100
# 918/918 [==============================] - 19s 20ms/step - loss: 4.3065e-05 - acc: 1.0000 - val_loss: 0.2473 - val_acc: 0.9568
#
# Epoch 00057: val_acc improved from 0.95062 to 0.95679, saving model to resnet34A.h5
# Epoch 58/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.8984e-05 - acc: 1.0000 - val_loss: 0.2249 - val_acc: 0.9630
#
# Epoch 00058: val_acc improved from 0.95679 to 0.96296, saving model to resnet34A.h5
# Epoch 59/100
# 918/918 [==============================] - 19s 20ms/step - loss: 6.6031e-04 - acc: 1.0000 - val_loss: 0.4802 - val_acc: 0.9383
#
# Epoch 00059: val_acc did not improve from 0.96296
# Epoch 60/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.8269e-04 - acc: 0.9989 - val_loss: 0.1452 - val_acc: 0.9630
#
# Epoch 00060: val_acc did not improve from 0.96296
# Epoch 61/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.4502e-05 - acc: 1.0000 - val_loss: 0.1351 - val_acc: 0.9691
#
# Epoch 00061: val_acc improved from 0.96296 to 0.96914, saving model to resnet34A.h5
# Epoch 62/100
# 918/918 [==============================] - 19s 20ms/step - loss: 7.8151e-04 - acc: 1.0000 - val_loss: 0.1329 - val_acc: 0.9630
#
# Epoch 00062: val_acc did not improve from 0.96914
# Epoch 63/100
# 918/918 [==============================] - 19s 20ms/step - loss: 7.0229e-04 - acc: 1.0000 - val_loss: 0.1730 - val_acc: 0.9568
#
# Epoch 00063: val_acc did not improve from 0.96914
# Epoch 64/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.3753e-04 - acc: 1.0000 - val_loss: 0.1396 - val_acc: 0.9568
#
# Epoch 00064: val_acc did not improve from 0.96914
# Epoch 65/100
# 918/918 [==============================] - 19s 20ms/step - loss: 3.4980e-05 - acc: 1.0000 - val_loss: 0.1310 - val_acc: 0.9691
#
# Epoch 00065: val_acc did not improve from 0.96914
# Epoch 66/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.5614e-05 - acc: 1.0000 - val_loss: 0.1317 - val_acc: 0.9630
#
# Epoch 00066: val_acc did not improve from 0.96914
# Epoch 67/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.3110e-04 - acc: 1.0000 - val_loss: 0.2134 - val_acc: 0.9568
#
# Epoch 00067: val_acc did not improve from 0.96914
# Epoch 68/100
# 918/918 [==============================] - 19s 20ms/step - loss: 7.2717e-05 - acc: 1.0000 - val_loss: 0.2230 - val_acc: 0.9568
#
# Epoch 00068: val_acc did not improve from 0.96914
# Epoch 69/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.1846e-05 - acc: 1.0000 - val_loss: 0.2146 - val_acc: 0.9568
#
# Epoch 00069: val_acc did not improve from 0.96914
# Epoch 70/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.1669e-05 - acc: 1.0000 - val_loss: 0.2113 - val_acc: 0.9630
#
# Epoch 00070: val_acc did not improve from 0.96914
# Epoch 71/100
# 918/918 [==============================] - 19s 20ms/step - loss: 7.1874e-05 - acc: 1.0000 - val_loss: 0.1801 - val_acc: 0.9568
#
# Epoch 00071: val_acc did not improve from 0.96914
# Epoch 72/100
# 918/918 [==============================] - 19s 20ms/step - loss: 9.4725e-06 - acc: 1.0000 - val_loss: 0.1765 - val_acc: 0.9630
#
# Epoch 00072: val_acc did not improve from 0.96914
# Epoch 73/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.1202e-05 - acc: 1.0000 - val_loss: 0.1767 - val_acc: 0.9691
#
# Epoch 00073: val_acc did not improve from 0.96914
# Epoch 74/100
# 918/918 [==============================] - 19s 20ms/step - loss: 3.2436e-05 - acc: 1.0000 - val_loss: 0.1763 - val_acc: 0.9691
#
# Epoch 00074: val_acc did not improve from 0.96914
# Epoch 75/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.2715e-05 - acc: 1.0000 - val_loss: 0.1757 - val_acc: 0.9630
#
# Epoch 00075: val_acc did not improve from 0.96914
# Epoch 76/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.9994e-05 - acc: 1.0000 - val_loss: 0.1762 - val_acc: 0.9630
#
# Epoch 00076: val_acc did not improve from 0.96914
# Epoch 77/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.8674e-06 - acc: 1.0000 - val_loss: 0.1717 - val_acc: 0.9630
#
# Epoch 00077: val_acc did not improve from 0.96914
# Epoch 78/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.6389e-05 - acc: 1.0000 - val_loss: 0.1721 - val_acc: 0.9630
#
# Epoch 00078: val_acc did not improve from 0.96914
# Epoch 79/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.7826e-06 - acc: 1.0000 - val_loss: 0.1723 - val_acc: 0.9691
#
# Epoch 00079: val_acc did not improve from 0.96914
# Epoch 80/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.1851e-05 - acc: 1.0000 - val_loss: 0.1724 - val_acc: 0.9691
#
# Epoch 00080: val_acc did not improve from 0.96914
# Epoch 81/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.7328e-05 - acc: 1.0000 - val_loss: 0.1728 - val_acc: 0.9691
#
# Epoch 00081: val_acc did not improve from 0.96914
# Epoch 82/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.2901e-04 - acc: 1.0000 - val_loss: 0.1698 - val_acc: 0.9630
#
# Epoch 00082: val_acc did not improve from 0.96914
# Epoch 83/100
# 918/918 [==============================] - 19s 20ms/step - loss: 3.9710e-05 - acc: 1.0000 - val_loss: 0.1732 - val_acc: 0.9630
#
# Epoch 00083: val_acc did not improve from 0.96914
# Epoch 84/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.3812e-05 - acc: 1.0000 - val_loss: 0.1745 - val_acc: 0.9630
#
# Epoch 00084: val_acc did not improve from 0.96914
# Epoch 85/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.2166e-05 - acc: 1.0000 - val_loss: 0.1759 - val_acc: 0.9630
#
# Epoch 00085: val_acc did not improve from 0.96914
# Epoch 86/100
# 918/918 [==============================] - 19s 20ms/step - loss: 3.9590e-05 - acc: 1.0000 - val_loss: 0.1705 - val_acc: 0.9630
#
# Epoch 00086: val_acc did not improve from 0.96914
# Epoch 87/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.9678e-05 - acc: 1.0000 - val_loss: 0.1636 - val_acc: 0.9568
#
# Epoch 00087: val_acc did not improve from 0.96914
# Epoch 88/100
# 918/918 [==============================] - 19s 20ms/step - loss: 2.3877e-05 - acc: 1.0000 - val_loss: 0.1688 - val_acc: 0.9753
#
# Epoch 00088: val_acc improved from 0.96914 to 0.97531, saving model to resnet34A.h5
# Epoch 89/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.6380e-06 - acc: 1.0000 - val_loss: 0.1686 - val_acc: 0.9753
#
# Epoch 00089: val_acc did not improve from 0.97531
# Epoch 90/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.2976e-06 - acc: 1.0000 - val_loss: 0.1690 - val_acc: 0.9691
#
# Epoch 00090: val_acc did not improve from 0.97531
# Epoch 91/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.7981e-06 - acc: 1.0000 - val_loss: 0.1696 - val_acc: 0.9691
#
# Epoch 00091: val_acc did not improve from 0.97531
# Epoch 92/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.3098e-05 - acc: 1.0000 - val_loss: 0.1698 - val_acc: 0.9691
#
# Epoch 00092: val_acc did not improve from 0.97531
# Epoch 93/100
# 918/918 [==============================] - 19s 20ms/step - loss: 9.1175e-06 - acc: 1.0000 - val_loss: 0.1698 - val_acc: 0.9691
#
# Epoch 00093: val_acc did not improve from 0.97531
# Epoch 94/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.2620e-06 - acc: 1.0000 - val_loss: 0.1693 - val_acc: 0.9691
#
# Epoch 00094: val_acc did not improve from 0.97531
# Epoch 95/100
# 918/918 [==============================] - 19s 20ms/step - loss: 1.5737e-05 - acc: 1.0000 - val_loss: 0.1751 - val_acc: 0.9691
#
# Epoch 00095: val_acc did not improve from 0.97531
# Epoch 96/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.6136e-06 - acc: 1.0000 - val_loss: 0.1762 - val_acc: 0.9691
#
# Epoch 00096: val_acc did not improve from 0.97531
# Epoch 97/100
# 918/918 [==============================] - 19s 20ms/step - loss: 6.5761e-06 - acc: 1.0000 - val_loss: 0.1757 - val_acc: 0.9691
#
# Epoch 00097: val_acc did not improve from 0.97531
# Epoch 98/100
# 918/918 [==============================] - 19s 20ms/step - loss: 5.2960e-06 - acc: 1.0000 - val_loss: 0.1751 - val_acc: 0.9691
#
# Epoch 00098: val_acc did not improve from 0.97531
# Epoch 99/100
# 918/918 [==============================] - 19s 20ms/step - loss: 8.2561e-06 - acc: 1.0000 - val_loss: 0.1749 - val_acc: 0.9691
#
# Epoch 00099: val_acc did not improve from 0.97531
# Epoch 100/100
# 918/918 [==============================] - 19s 20ms/step - loss: 7.3162e-06 - acc: 1.0000 - val_loss: 0.1749 - val_acc: 0.9691
#
# Epoch 00100: val_acc did not improve from 0.97531
# Total time:  1907.8111066818237

# %%
model = keras.models.load_model("resnet34A.h5")
pred = model.evaluate(x_test, y_test)
print('loss is', pred[0])
print('accuracy is', pred[1])
# Out:
# 120/120 [==============================] - 3s 23ms/step
# loss is 0.06675388770430193
# accuracy is 0.9916666666666667

# %%
np.save('r34A_loss.npy', history.history['loss'])
np.save('r34A_acc.npy', history.history['acc'])
np.save('r34A_vloss.npy', history.history['val_loss'])
np.save('r34A_vacc.npy', history.history['val_acc'])
